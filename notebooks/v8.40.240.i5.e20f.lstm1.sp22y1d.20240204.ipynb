# %%
import train
import numpy as np
import api.capital_features_api as cf
import pandas as pd
import mplfinance as mpf
from datetime import datetime
import joblib
import matplotlib.pyplot as plt
import model_util as mu
from tensorflow import keras
import os
import shutil

model_name = 'v8.40.240.i5.e20f.lstm1.sp22y1d.20240204'
model_dir = './model/' + model_name + '/'
os.makedirs(model_dir, exist_ok=True)
scaler_save_file = model_dir + 'scaler.save'
scaler_json_file = model_dir + 'scaler.json'
model_h5_file = model_dir + 'model.h5'
model_tf_dir_file = model_dir + 'model_tf'
model_tf_dir_scaler_json_file = model_tf_dir_file + '/scaler.json'

# %%
train_ud_data = cf.get_train_data(cf.docker_train_data_url, train_config_id=2059170)
validation_ud_data = cf.get_train_data(cf.docker_train_data_url, train_config_id=2059171)
Y_ud_train = train_ud_data['upSignals']
Y_ud_val = validation_ud_data['upSignals']

# %%
train_ud_dataset, validation_ud_dataset, scaler_ud = train.to_dataset(train_ud_data, validation_ud_data, Y_ud_train, Y_ud_val)
weights_ud = train.to_weights(Y_ud_train)
joblib.dump(scaler_ud, scaler_save_file)
train.save_scaler(scaler_ud, scaler_json_file)

# %%
model_ud, callbacks_ud = train.get_model(40, 5, model_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 40, 128)           68608
#
#  dropout (Dropout)           (None, 40, 128)           0
#
#  batch_normalization (BatchN  (None, 40, 128)          512
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense (Dense)               (None, 256)               16640
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 135,681
# Trainable params: 135,297
# Non-trainable params: 384
# _________________________________________________________________

# %%
his_ud = model_ud.fit(train_ud_dataset, epochs=500, validation_data=validation_ud_dataset, verbose=1, callbacks=callbacks_ud, class_weight=weights_ud)
model_ud.save(model_h5_file)
model_ud.save(model_tf_dir_file, save_format='tf')
shutil.copy2(scaler_json_file, model_tf_dir_scaler_json_file)
# Out:
# Epoch 1/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.7020 - accuracy: 0.5215 - precision: 0.5196 - recall: 0.5695
# Epoch 00001: val_loss improved from inf to 0.68994, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_01.ckpt
# 9354/9354 [==============================] - 235s 24ms/step - loss: 0.7020 - accuracy: 0.5215 - precision: 0.5196 - recall: 0.5695 - val_loss: 0.6899 - val_accuracy: 0.5409 - val_precision: 0.5498 - val_recall: 0.4508 - lr: 0.0010
# Epoch 2/500
# 9352/9354 [============================>.] - ETA: 0s - loss: 0.6886 - accuracy: 0.5422 - precision: 0.5433 - recall: 0.5301
# Epoch 00002: val_loss improved from 0.68994 to 0.68590, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_02.ckpt
# 9354/9354 [==============================] - 235s 25ms/step - loss: 0.6886 - accuracy: 0.5422 - precision: 0.5433 - recall: 0.5301 - val_loss: 0.6859 - val_accuracy: 0.5481 - val_precision: 0.5392 - val_recall: 0.6610 - lr: 0.0010
# Epoch 3/500
# 9352/9354 [============================>.] - ETA: 0s - loss: 0.6867 - accuracy: 0.5496 - precision: 0.5516 - recall: 0.5302
# Epoch 00003: val_loss did not improve from 0.68590
# 9354/9354 [==============================] - 237s 25ms/step - loss: 0.6867 - accuracy: 0.5496 - precision: 0.5516 - recall: 0.5302 - val_loss: 0.6861 - val_accuracy: 0.5523 - val_precision: 0.5517 - val_recall: 0.5590 - lr: 0.0010
# Epoch 4/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6854 - accuracy: 0.5537 - precision: 0.5551 - recall: 0.5406
# Epoch 00004: val_loss improved from 0.68590 to 0.68305, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_04.ckpt
# 9354/9354 [==============================] - 237s 25ms/step - loss: 0.6854 - accuracy: 0.5537 - precision: 0.5551 - recall: 0.5406 - val_loss: 0.6830 - val_accuracy: 0.5576 - val_precision: 0.5539 - val_recall: 0.5923 - lr: 0.0010
# Epoch 5/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6840 - accuracy: 0.5578 - precision: 0.5584 - recall: 0.5526
# Epoch 00005: val_loss improved from 0.68305 to 0.68223, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_05.ckpt
# 9354/9354 [==============================] - 238s 25ms/step - loss: 0.6840 - accuracy: 0.5578 - precision: 0.5584 - recall: 0.5526 - val_loss: 0.6822 - val_accuracy: 0.5608 - val_precision: 0.5523 - val_recall: 0.6420 - lr: 0.0010
# Epoch 6/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6816 - accuracy: 0.5648 - precision: 0.5668 - recall: 0.5504
# Epoch 00006: val_loss improved from 0.68223 to 0.68013, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_06.ckpt
# 9354/9354 [==============================] - 237s 25ms/step - loss: 0.6816 - accuracy: 0.5648 - precision: 0.5668 - recall: 0.5504 - val_loss: 0.6801 - val_accuracy: 0.5643 - val_precision: 0.5548 - val_recall: 0.6509 - lr: 0.0010
# Epoch 7/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.6790 - accuracy: 0.5705 - precision: 0.5728 - recall: 0.5546
# Epoch 00007: val_loss improved from 0.68013 to 0.67917, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_07.ckpt
# 9354/9354 [==============================] - 237s 25ms/step - loss: 0.6790 - accuracy: 0.5705 - precision: 0.5728 - recall: 0.5546 - val_loss: 0.6792 - val_accuracy: 0.5654 - val_precision: 0.5525 - val_recall: 0.6893 - lr: 0.0010
# Epoch 8/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6757 - accuracy: 0.5772 - precision: 0.5794 - recall: 0.5629
# Epoch 00008: val_loss improved from 0.67917 to 0.67659, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_08.ckpt
# 9354/9354 [==============================] - 239s 26ms/step - loss: 0.6757 - accuracy: 0.5772 - precision: 0.5794 - recall: 0.5629 - val_loss: 0.6766 - val_accuracy: 0.5713 - val_precision: 0.5632 - val_recall: 0.6355 - lr: 0.0010
# Epoch 9/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6718 - accuracy: 0.5836 - precision: 0.5849 - recall: 0.5761
# Epoch 00009: val_loss did not improve from 0.67659
# 9354/9354 [==============================] - 237s 25ms/step - loss: 0.6718 - accuracy: 0.5836 - precision: 0.5849 - recall: 0.5761 - val_loss: 0.6767 - val_accuracy: 0.5743 - val_precision: 0.5713 - val_recall: 0.5953 - lr: 0.0010
# Epoch 10/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6679 - accuracy: 0.5899 - precision: 0.5913 - recall: 0.5824
# Epoch 00010: val_loss improved from 0.67659 to 0.67468, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_10.ckpt
# 9354/9354 [==============================] - 237s 25ms/step - loss: 0.6679 - accuracy: 0.5899 - precision: 0.5913 - recall: 0.5824 - val_loss: 0.6747 - val_accuracy: 0.5785 - val_precision: 0.5695 - val_recall: 0.6432 - lr: 0.0010
# Epoch 11/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.6628 - accuracy: 0.5976 - precision: 0.5989 - recall: 0.5908
# Epoch 00011: val_loss improved from 0.67468 to 0.67190, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_11.ckpt
# 9354/9354 [==============================] - 236s 25ms/step - loss: 0.6628 - accuracy: 0.5976 - precision: 0.5989 - recall: 0.5908 - val_loss: 0.6719 - val_accuracy: 0.5784 - val_precision: 0.5718 - val_recall: 0.6241 - lr: 0.0010
# Epoch 12/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6573 - accuracy: 0.6049 - precision: 0.6063 - recall: 0.5983
# Epoch 00012: val_loss did not improve from 0.67190
# 9354/9354 [==============================] - 238s 25ms/step - loss: 0.6573 - accuracy: 0.6049 - precision: 0.6063 - recall: 0.5983 - val_loss: 0.6725 - val_accuracy: 0.5811 - val_precision: 0.5755 - val_recall: 0.6185 - lr: 0.0010
# Epoch 13/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.6514 - accuracy: 0.6124 - precision: 0.6139 - recall: 0.6057
# Epoch 00013: val_loss improved from 0.67190 to 0.67102, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_13.ckpt
# 9354/9354 [==============================] - 238s 25ms/step - loss: 0.6514 - accuracy: 0.6124 - precision: 0.6139 - recall: 0.6057 - val_loss: 0.6710 - val_accuracy: 0.5833 - val_precision: 0.5727 - val_recall: 0.6561 - lr: 0.0010
# Epoch 14/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.6455 - accuracy: 0.6198 - precision: 0.6216 - recall: 0.6124
# Epoch 00014: val_loss did not improve from 0.67102
# 9354/9354 [==============================] - 236s 25ms/step - loss: 0.6455 - accuracy: 0.6198 - precision: 0.6215 - recall: 0.6124 - val_loss: 0.6744 - val_accuracy: 0.5854 - val_precision: 0.5814 - val_recall: 0.6100 - lr: 0.0010
# Epoch 15/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6398 - accuracy: 0.6264 - precision: 0.6295 - recall: 0.6143
# Epoch 00015: val_loss improved from 0.67102 to 0.66775, saving model to ./checkpoint/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/epoch_15.ckpt
# 9354/9354 [==============================] - 239s 26ms/step - loss: 0.6398 - accuracy: 0.6264 - precision: 0.6295 - recall: 0.6143 - val_loss: 0.6677 - val_accuracy: 0.5860 - val_precision: 0.5844 - val_recall: 0.5952 - lr: 0.0010
# Epoch 16/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.6329 - accuracy: 0.6344 - precision: 0.6377 - recall: 0.6228
# Epoch 00016: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 236s 25ms/step - loss: 0.6329 - accuracy: 0.6344 - precision: 0.6376 - recall: 0.6228 - val_loss: 0.6733 - val_accuracy: 0.5873 - val_precision: 0.5837 - val_recall: 0.6087 - lr: 0.0010
# Epoch 17/500
# 9352/9354 [============================>.] - ETA: 0s - loss: 0.6262 - accuracy: 0.6426 - precision: 0.6460 - recall: 0.6309
# Epoch 00017: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 239s 26ms/step - loss: 0.6262 - accuracy: 0.6425 - precision: 0.6460 - recall: 0.6309 - val_loss: 0.6792 - val_accuracy: 0.5844 - val_precision: 0.5727 - val_recall: 0.6647 - lr: 0.0010
# Epoch 18/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.6198 - accuracy: 0.6492 - precision: 0.6537 - recall: 0.6345
# Epoch 00018: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 237s 25ms/step - loss: 0.6198 - accuracy: 0.6492 - precision: 0.6537 - recall: 0.6345 - val_loss: 0.6819 - val_accuracy: 0.5851 - val_precision: 0.5808 - val_recall: 0.6121 - lr: 0.0010
# Epoch 19/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.6122 - accuracy: 0.6565 - precision: 0.6602 - recall: 0.6449
# Epoch 00019: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 239s 26ms/step - loss: 0.6122 - accuracy: 0.6565 - precision: 0.6602 - recall: 0.6449 - val_loss: 0.6886 - val_accuracy: 0.5839 - val_precision: 0.5812 - val_recall: 0.6001 - lr: 0.0010
# Epoch 20/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.6045 - accuracy: 0.6655 - precision: 0.6697 - recall: 0.6531
# Epoch 00020: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 239s 26ms/step - loss: 0.6045 - accuracy: 0.6655 - precision: 0.6697 - recall: 0.6531 - val_loss: 0.7011 - val_accuracy: 0.5822 - val_precision: 0.5738 - val_recall: 0.6384 - lr: 0.0010
# Epoch 21/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.5973 - accuracy: 0.6727 - precision: 0.6783 - recall: 0.6569
# Epoch 00021: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 235s 25ms/step - loss: 0.5973 - accuracy: 0.6727 - precision: 0.6783 - recall: 0.6569 - val_loss: 0.6999 - val_accuracy: 0.5853 - val_precision: 0.5835 - val_recall: 0.5963 - lr: 0.0010
# Epoch 22/500
# 9352/9354 [============================>.] - ETA: 0s - loss: 0.5892 - accuracy: 0.6808 - precision: 0.6869 - recall: 0.6647
# Epoch 00022: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 235s 25ms/step - loss: 0.5892 - accuracy: 0.6808 - precision: 0.6869 - recall: 0.6647 - val_loss: 0.7167 - val_accuracy: 0.5784 - val_precision: 0.5696 - val_recall: 0.6419 - lr: 0.0010
# Epoch 23/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.5811 - accuracy: 0.6884 - precision: 0.6949 - recall: 0.6717
# Epoch 00023: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 236s 25ms/step - loss: 0.5811 - accuracy: 0.6884 - precision: 0.6949 - recall: 0.6717 - val_loss: 0.7221 - val_accuracy: 0.5798 - val_precision: 0.5751 - val_recall: 0.6112 - lr: 0.0010
# Epoch 24/500
# 9352/9354 [============================>.] - ETA: 0s - loss: 0.5738 - accuracy: 0.6952 - precision: 0.7008 - recall: 0.6814
# Epoch 00024: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 235s 25ms/step - loss: 0.5738 - accuracy: 0.6952 - precision: 0.7008 - recall: 0.6814 - val_loss: 0.7290 - val_accuracy: 0.5779 - val_precision: 0.5739 - val_recall: 0.6044 - lr: 0.0010
# Epoch 25/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.5657 - accuracy: 0.7024 - precision: 0.7088 - recall: 0.6869
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00025: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 238s 25ms/step - loss: 0.5657 - accuracy: 0.7024 - precision: 0.7088 - recall: 0.6869 - val_loss: 0.7277 - val_accuracy: 0.5794 - val_precision: 0.5781 - val_recall: 0.5879 - lr: 0.0010
# Epoch 26/500
# 9352/9354 [============================>.] - ETA: 0s - loss: 0.5383 - accuracy: 0.7239 - precision: 0.7285 - recall: 0.7138
# Epoch 00026: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 234s 25ms/step - loss: 0.5383 - accuracy: 0.7239 - precision: 0.7285 - recall: 0.7138 - val_loss: 0.7693 - val_accuracy: 0.5790 - val_precision: 0.5750 - val_recall: 0.6053 - lr: 5.0000e-04
# Epoch 27/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.5276 - accuracy: 0.7310 - precision: 0.7381 - recall: 0.7161
# Epoch 00027: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 232s 25ms/step - loss: 0.5276 - accuracy: 0.7310 - precision: 0.7381 - recall: 0.7161 - val_loss: 0.7730 - val_accuracy: 0.5785 - val_precision: 0.5746 - val_recall: 0.6050 - lr: 5.0000e-04
# Epoch 28/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.5203 - accuracy: 0.7367 - precision: 0.7439 - recall: 0.7219
# Epoch 00028: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 232s 25ms/step - loss: 0.5203 - accuracy: 0.7367 - precision: 0.7439 - recall: 0.7219 - val_loss: 0.7681 - val_accuracy: 0.5784 - val_precision: 0.5737 - val_recall: 0.6106 - lr: 5.0000e-04
# Epoch 29/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.5147 - accuracy: 0.7417 - precision: 0.7499 - recall: 0.7255
# Epoch 00029: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 231s 25ms/step - loss: 0.5147 - accuracy: 0.7417 - precision: 0.7499 - recall: 0.7255 - val_loss: 0.7770 - val_accuracy: 0.5787 - val_precision: 0.5850 - val_recall: 0.5416 - lr: 5.0000e-04
# Epoch 30/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.5075 - accuracy: 0.7464 - precision: 0.7550 - recall: 0.7296
# Epoch 00030: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 232s 25ms/step - loss: 0.5075 - accuracy: 0.7464 - precision: 0.7550 - recall: 0.7296 - val_loss: 0.8068 - val_accuracy: 0.5759 - val_precision: 0.5679 - val_recall: 0.6352 - lr: 5.0000e-04
# Epoch 31/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.5024 - accuracy: 0.7507 - precision: 0.7594 - recall: 0.7341
# Epoch 00031: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 231s 25ms/step - loss: 0.5024 - accuracy: 0.7507 - precision: 0.7594 - recall: 0.7341 - val_loss: 0.8270 - val_accuracy: 0.5750 - val_precision: 0.5688 - val_recall: 0.6202 - lr: 5.0000e-04
# Epoch 32/500
# 9353/9354 [============================>.] - ETA: 0s - loss: 0.4960 - accuracy: 0.7546 - precision: 0.7643 - recall: 0.7363
# Epoch 00032: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 230s 25ms/step - loss: 0.4960 - accuracy: 0.7546 - precision: 0.7643 - recall: 0.7363 - val_loss: 0.8254 - val_accuracy: 0.5745 - val_precision: 0.5694 - val_recall: 0.6110 - lr: 5.0000e-04
# Epoch 33/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.4917 - accuracy: 0.7582 - precision: 0.7681 - recall: 0.7398
# Epoch 00033: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 230s 25ms/step - loss: 0.4917 - accuracy: 0.7582 - precision: 0.7681 - recall: 0.7398 - val_loss: 0.8373 - val_accuracy: 0.5743 - val_precision: 0.5699 - val_recall: 0.6051 - lr: 5.0000e-04
# Epoch 34/500
# 9352/9354 [============================>.] - ETA: 0s - loss: 0.4854 - accuracy: 0.7629 - precision: 0.7720 - recall: 0.7463
# Epoch 00034: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 231s 25ms/step - loss: 0.4854 - accuracy: 0.7629 - precision: 0.7720 - recall: 0.7463 - val_loss: 0.8334 - val_accuracy: 0.5754 - val_precision: 0.5744 - val_recall: 0.5822 - lr: 5.0000e-04
# Epoch 35/500
# 9354/9354 [==============================] - ETA: 0s - loss: 0.4809 - accuracy: 0.7663 - precision: 0.7759 - recall: 0.7490Restoring model weights from the end of the best epoch: 15.
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00035: val_loss did not improve from 0.66775
# 9354/9354 [==============================] - 237s 25ms/step - loss: 0.4809 - accuracy: 0.7663 - precision: 0.7759 - recall: 0.7490 - val_loss: 0.8552 - val_accuracy: 0.5730 - val_precision: 0.5714 - val_recall: 0.5842 - lr: 5.0000e-04
# Epoch 35: early stopping
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./model/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/model_tf/assets
# INFO:tensorflow:Assets written to: ./model/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/model_tf/assets
# './model/v8.40.240.i5.e20f.lstm1.sp22y1d.20240204/model_tf/scaler.json'

# %%
plt.plot(his_ud.history['accuracy'], label='accuracy')
plt.plot(his_ud.history['val_accuracy'], label='val_accuracy')
plt.plot(his_ud.history['loss'], label='loss')
plt.plot(his_ud.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
model_ud = keras.models.load_model(model_tf_dir_file)
scaler_ud = joblib.load(scaler_save_file)

# %%
prediction_data = cf.get_prediction_data(cf.docker_prediction_data_url, train_config_id=2059170, start="2021-07-11", end=datetime.now().strftime("%Y-%m-%d"), code="SPY")
kline = cf.get_kline_histroy(cf.docker_kline_history_url, start="2021-07-11", end=datetime.now().strftime("%Y-%m-%d"), code='SPY')
df = cf.his_to_df(kline)

# %%
X_prediction_scaled = train.to_prediction_scaled(prediction_data, scaler_ud)
Y_ud_prediction = model_ud.predict(X_prediction_scaled)
# Out:
# 21/21 [==============================] - 1s 14ms/step

# %%
predictions_ud_series = pd.Series(Y_ud_prediction.flatten(), index=df.index)
buy_signals = np.full(df.shape[0], np.nan)  # 含 NaN 的数组，与 df 的长度一致
buy_signals[predictions_ud_series > 0.8] = df['low'][predictions_ud_series > 0.8] * 0.99
buy_markers = mpf.make_addplot(buy_signals, type='scatter', markersize=50, marker='^', color='g')

sell_signals = np.full(df.shape[0], np.nan)  # 含 NaN 的数组，与 df 的长度一致
sell_signals[predictions_ud_series < 0.1] = df['high'][predictions_ud_series < 0.1] * 1.01
sell_signals = mpf.make_addplot(sell_signals, type='scatter', markersize=50, marker='_', color='gray')

mpf.plot(df, type='candle', style='charles', addplot=[buy_markers, sell_signals], volume=True, figsize=(24, 16))
# Out:
# /usr/local/lib/python3.8/dist-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
model_ud, callbacks_ud = train.get_model(5, 40, model_name, 1.5625e-05)
model_ud.load_weights('./epoch/'+model_name+'/epoch_531.ckpt')
model_ud.save(model_h5_file)
model_ud.save(model_tf_dir_file, save_format='tf')
shutil.copy2(scaler_json_file, model_tf_dir_scaler_json_file)
