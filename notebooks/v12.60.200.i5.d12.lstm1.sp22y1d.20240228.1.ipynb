# %%
import train
import numpy as np
import api.capital_features_api as cf
import pandas as pd
import mplfinance as mpf
from datetime import datetime
import joblib
import matplotlib.pyplot as plt
import model_util as mu
from tensorflow import keras
import os
import shutil

model_name = 'v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2'
model_dir = './model/' + model_name + '/'
os.makedirs(model_dir, exist_ok=True)
scaler_save_file = model_dir + 'scaler.save'
scaler_json_file = model_dir + 'scaler.json'
model_h5_file = model_dir + 'model.h5'
model_tf_dir_file = model_dir + 'model_tf'
model_tf_dir_scaler_json_file = model_tf_dir_file + '/scaler.json'

# %%
train_ud_data = cf.get_train_data(cf.docker_train_data_url, train_config_id=2059182)
validation_ud_data = cf.get_train_data(cf.docker_train_data_url, train_config_id=2059183)
Y_ud_train = train_ud_data['upSignals']
Y_ud_val = validation_ud_data['upSignals']

# %%
train_ud_dataset, validation_ud_dataset, scaler_ud = train.to_dataset(train_ud_data['features'], validation_ud_data['features'], Y_ud_train, Y_ud_val)
weights_ud = train.to_weights(Y_ud_train)
joblib.dump(scaler_ud, scaler_save_file)
train.save_scaler(scaler_ud, scaler_json_file)

# %%
model_ud, callbacks_ud = train.get_model(60, 5, model_name)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 60, 128)           68608
#
#  dropout (Dropout)           (None, 60, 128)           0
#
#  batch_normalization (BatchN  (None, 60, 128)          512
#  ormalization)
#
#  lstm_1 (LSTM)               (None, 64)                49408
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  batch_normalization_1 (Batc  (None, 64)               256
#  hNormalization)
#
#  dense (Dense)               (None, 256)               16640
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 135,681
# Trainable params: 135,297
# Non-trainable params: 384
# _________________________________________________________________

# %%
his_ud = model_ud.fit(train_ud_dataset, epochs=500, validation_data=validation_ud_dataset, verbose=1, callbacks=callbacks_ud, class_weight=weights_ud)
model_ud.save(model_h5_file)
model_ud.save(model_tf_dir_file, save_format='tf')
shutil.copy2(scaler_json_file, model_tf_dir_scaler_json_file)
# Out:
# Epoch 1/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.7038 - accuracy: 0.5133 - precision: 0.4841 - recall: 0.6102
# Epoch 00001: val_loss improved from inf to 0.69821, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_01.ckpt
# 8613/8613 [==============================] - 235s 26ms/step - loss: 0.7038 - accuracy: 0.5133 - precision: 0.4841 - recall: 0.6102 - val_loss: 0.6982 - val_accuracy: 0.4673 - val_precision: 0.4668 - val_recall: 0.9976 - lr: 0.0010
# Epoch 2/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6915 - accuracy: 0.5162 - precision: 0.4879 - recall: 0.6863
# Epoch 00002: val_loss improved from 0.69821 to 0.69196, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_02.ckpt
# 8613/8613 [==============================] - 233s 27ms/step - loss: 0.6915 - accuracy: 0.5162 - precision: 0.4879 - recall: 0.6863 - val_loss: 0.6920 - val_accuracy: 0.5186 - val_precision: 0.4865 - val_recall: 0.5816 - lr: 0.0010
# Epoch 3/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6912 - accuracy: 0.5191 - precision: 0.4897 - recall: 0.6606
# Epoch 00003: val_loss improved from 0.69196 to 0.69104, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_03.ckpt
# 8613/8613 [==============================] - 233s 27ms/step - loss: 0.6912 - accuracy: 0.5191 - precision: 0.4897 - recall: 0.6606 - val_loss: 0.6910 - val_accuracy: 0.5181 - val_precision: 0.4843 - val_recall: 0.5144 - lr: 0.0010
# Epoch 4/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.6908 - accuracy: 0.5202 - precision: 0.4906 - recall: 0.6637
# Epoch 00004: val_loss did not improve from 0.69104
# 8613/8613 [==============================] - 229s 27ms/step - loss: 0.6908 - accuracy: 0.5202 - precision: 0.4906 - recall: 0.6637 - val_loss: 0.6932 - val_accuracy: 0.5145 - val_precision: 0.4787 - val_recall: 0.4611 - lr: 0.0010
# Epoch 5/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.6925 - accuracy: 0.5124 - precision: 0.4845 - recall: 0.6552
# Epoch 00005: val_loss did not improve from 0.69104
# 8613/8613 [==============================] - 233s 27ms/step - loss: 0.6925 - accuracy: 0.5124 - precision: 0.4845 - recall: 0.6552 - val_loss: 0.6930 - val_accuracy: 0.5000 - val_precision: 0.4791 - val_recall: 0.8270 - lr: 0.0010
# Epoch 6/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6916 - accuracy: 0.5158 - precision: 0.4872 - recall: 0.6658
# Epoch 00006: val_loss did not improve from 0.69104
# 8613/8613 [==============================] - 239s 28ms/step - loss: 0.6916 - accuracy: 0.5158 - precision: 0.4872 - recall: 0.6658 - val_loss: 0.7088 - val_accuracy: 0.5303 - val_precision: 0.4939 - val_recall: 0.2892 - lr: 0.0010
# Epoch 7/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6913 - accuracy: 0.5186 - precision: 0.4894 - recall: 0.6632
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00007: val_loss did not improve from 0.69104
# 8613/8613 [==============================] - 233s 27ms/step - loss: 0.6913 - accuracy: 0.5186 - precision: 0.4894 - recall: 0.6632 - val_loss: 0.7005 - val_accuracy: 0.5296 - val_precision: 0.4933 - val_recall: 0.3166 - lr: 0.0010
# Epoch 8/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6901 - accuracy: 0.5228 - precision: 0.4928 - recall: 0.6772
# Epoch 00008: val_loss improved from 0.69104 to 0.69019, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_08.ckpt
# 8613/8613 [==============================] - 236s 27ms/step - loss: 0.6901 - accuracy: 0.5228 - precision: 0.4928 - recall: 0.6772 - val_loss: 0.6902 - val_accuracy: 0.5212 - val_precision: 0.4892 - val_recall: 0.6029 - lr: 5.0000e-04
# Epoch 9/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.6899 - accuracy: 0.5246 - precision: 0.4940 - recall: 0.6645
# Epoch 00009: val_loss did not improve from 0.69019
# 8613/8613 [==============================] - 239s 28ms/step - loss: 0.6899 - accuracy: 0.5246 - precision: 0.4940 - recall: 0.6645 - val_loss: 0.6915 - val_accuracy: 0.5108 - val_precision: 0.4840 - val_recall: 0.7407 - lr: 5.0000e-04
# Epoch 10/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6898 - accuracy: 0.5245 - precision: 0.4940 - recall: 0.6642
# Epoch 00010: val_loss improved from 0.69019 to 0.68932, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_10.ckpt
# 8613/8613 [==============================] - 250s 29ms/step - loss: 0.6898 - accuracy: 0.5246 - precision: 0.4940 - recall: 0.6642 - val_loss: 0.6893 - val_accuracy: 0.5275 - val_precision: 0.4941 - val_recall: 0.5459 - lr: 5.0000e-04
# Epoch 11/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.6896 - accuracy: 0.5260 - precision: 0.4951 - recall: 0.6561
# Epoch 00011: val_loss did not improve from 0.68932
# 8613/8613 [==============================] - 245s 28ms/step - loss: 0.6896 - accuracy: 0.5260 - precision: 0.4951 - recall: 0.6561 - val_loss: 0.6950 - val_accuracy: 0.4956 - val_precision: 0.4777 - val_recall: 0.8731 - lr: 5.0000e-04
# Epoch 12/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6894 - accuracy: 0.5271 - precision: 0.4960 - recall: 0.6526
# Epoch 00012: val_loss did not improve from 0.68932
# 8613/8613 [==============================] - 240s 28ms/step - loss: 0.6894 - accuracy: 0.5271 - precision: 0.4960 - recall: 0.6526 - val_loss: 0.6911 - val_accuracy: 0.5173 - val_precision: 0.4881 - val_recall: 0.7180 - lr: 5.0000e-04
# Epoch 13/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6890 - accuracy: 0.5288 - precision: 0.4973 - recall: 0.6468
# Epoch 00013: val_loss did not improve from 0.68932
# 8613/8613 [==============================] - 246s 29ms/step - loss: 0.6890 - accuracy: 0.5288 - precision: 0.4973 - recall: 0.6468 - val_loss: 0.6917 - val_accuracy: 0.5161 - val_precision: 0.4870 - val_recall: 0.7027 - lr: 5.0000e-04
# Epoch 14/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6886 - accuracy: 0.5315 - precision: 0.4995 - recall: 0.6426
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00014: val_loss did not improve from 0.68932
# 8613/8613 [==============================] - 240s 28ms/step - loss: 0.6886 - accuracy: 0.5315 - precision: 0.4995 - recall: 0.6426 - val_loss: 0.6917 - val_accuracy: 0.5175 - val_precision: 0.4890 - val_recall: 0.7632 - lr: 5.0000e-04
# Epoch 15/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.6876 - accuracy: 0.5348 - precision: 0.5023 - recall: 0.6327
# Epoch 00015: val_loss improved from 0.68932 to 0.68818, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_15.ckpt
# 8613/8613 [==============================] - 240s 28ms/step - loss: 0.6876 - accuracy: 0.5348 - precision: 0.5023 - recall: 0.6327 - val_loss: 0.6882 - val_accuracy: 0.5314 - val_precision: 0.4982 - val_recall: 0.6339 - lr: 2.5000e-04
# Epoch 16/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6873 - accuracy: 0.5357 - precision: 0.5030 - recall: 0.6317
# Epoch 00016: val_loss did not improve from 0.68818
# 8613/8613 [==============================] - 243s 28ms/step - loss: 0.6873 - accuracy: 0.5357 - precision: 0.5030 - recall: 0.6317 - val_loss: 0.6886 - val_accuracy: 0.5329 - val_precision: 0.4994 - val_recall: 0.6421 - lr: 2.5000e-04
# Epoch 17/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.5369 - precision: 0.5041 - recall: 0.6328
# Epoch 00017: val_loss did not improve from 0.68818
# 8613/8613 [==============================] - 244s 28ms/step - loss: 0.6870 - accuracy: 0.5369 - precision: 0.5041 - recall: 0.6328 - val_loss: 0.6896 - val_accuracy: 0.5266 - val_precision: 0.4947 - val_recall: 0.7056 - lr: 2.5000e-04
# Epoch 18/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6866 - accuracy: 0.5382 - precision: 0.5052 - recall: 0.6325
# Epoch 00018: val_loss did not improve from 0.68818
# 8613/8613 [==============================] - 250s 29ms/step - loss: 0.6866 - accuracy: 0.5382 - precision: 0.5052 - recall: 0.6325 - val_loss: 0.6892 - val_accuracy: 0.5252 - val_precision: 0.4939 - val_recall: 0.7334 - lr: 2.5000e-04
# Epoch 19/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6863 - accuracy: 0.5395 - precision: 0.5064 - recall: 0.6319
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00019: val_loss improved from 0.68818 to 0.68815, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_19.ckpt
# 8613/8613 [==============================] - 258s 30ms/step - loss: 0.6863 - accuracy: 0.5395 - precision: 0.5064 - recall: 0.6319 - val_loss: 0.6882 - val_accuracy: 0.5310 - val_precision: 0.4980 - val_recall: 0.6865 - lr: 2.5000e-04
# Epoch 20/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6854 - accuracy: 0.5416 - precision: 0.5081 - recall: 0.6326
# Epoch 00020: val_loss improved from 0.68815 to 0.68766, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_20.ckpt
# 8613/8613 [==============================] - 266s 31ms/step - loss: 0.6854 - accuracy: 0.5416 - precision: 0.5081 - recall: 0.6326 - val_loss: 0.6877 - val_accuracy: 0.5319 - val_precision: 0.4986 - val_recall: 0.6648 - lr: 1.2500e-04
# Epoch 21/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.6851 - accuracy: 0.5422 - precision: 0.5086 - recall: 0.6347
# Epoch 00021: val_loss improved from 0.68766 to 0.68725, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_21.ckpt
# 8613/8613 [==============================] - 259s 30ms/step - loss: 0.6851 - accuracy: 0.5422 - precision: 0.5086 - recall: 0.6347 - val_loss: 0.6872 - val_accuracy: 0.5344 - val_precision: 0.5006 - val_recall: 0.6320 - lr: 1.2500e-04
# Epoch 22/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6849 - accuracy: 0.5427 - precision: 0.5091 - recall: 0.6341
# Epoch 00022: val_loss improved from 0.68725 to 0.68672, saving model to ./checkpoint/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/epoch_22.ckpt
# 8613/8613 [==============================] - 253s 29ms/step - loss: 0.6849 - accuracy: 0.5427 - precision: 0.5091 - recall: 0.6341 - val_loss: 0.6867 - val_accuracy: 0.5362 - val_precision: 0.5023 - val_recall: 0.6239 - lr: 1.2500e-04
# Epoch 23/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6845 - accuracy: 0.5441 - precision: 0.5103 - recall: 0.6335
# Epoch 00023: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 257s 30ms/step - loss: 0.6845 - accuracy: 0.5441 - precision: 0.5103 - recall: 0.6335 - val_loss: 0.6874 - val_accuracy: 0.5336 - val_precision: 0.5000 - val_recall: 0.6540 - lr: 1.2500e-04
# Epoch 24/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6842 - accuracy: 0.5446 - precision: 0.5108 - recall: 0.6355
# Epoch 00024: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 259s 30ms/step - loss: 0.6842 - accuracy: 0.5446 - precision: 0.5108 - recall: 0.6355 - val_loss: 0.6881 - val_accuracy: 0.5282 - val_precision: 0.4960 - val_recall: 0.7049 - lr: 1.2500e-04
# Epoch 25/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.6838 - accuracy: 0.5446 - precision: 0.5107 - recall: 0.6384
# Epoch 00025: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 255s 30ms/step - loss: 0.6838 - accuracy: 0.5446 - precision: 0.5107 - recall: 0.6385 - val_loss: 0.6873 - val_accuracy: 0.5337 - val_precision: 0.5001 - val_recall: 0.6377 - lr: 1.2500e-04
# Epoch 26/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6836 - accuracy: 0.5463 - precision: 0.5123 - recall: 0.6346
# Epoch 26: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00026: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 254s 30ms/step - loss: 0.6836 - accuracy: 0.5463 - precision: 0.5123 - recall: 0.6346 - val_loss: 0.6872 - val_accuracy: 0.5346 - val_precision: 0.5008 - val_recall: 0.6579 - lr: 1.2500e-04
# Epoch 27/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6829 - accuracy: 0.5478 - precision: 0.5135 - recall: 0.6357
# Epoch 00027: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 260s 30ms/step - loss: 0.6829 - accuracy: 0.5478 - precision: 0.5135 - recall: 0.6357 - val_loss: 0.6874 - val_accuracy: 0.5335 - val_precision: 0.4999 - val_recall: 0.6562 - lr: 6.2500e-05
# Epoch 28/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6827 - accuracy: 0.5489 - precision: 0.5146 - recall: 0.6345
# Epoch 00028: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 258s 30ms/step - loss: 0.6827 - accuracy: 0.5489 - precision: 0.5146 - recall: 0.6345 - val_loss: 0.6878 - val_accuracy: 0.5338 - val_precision: 0.5002 - val_recall: 0.6490 - lr: 6.2500e-05
# Epoch 29/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6822 - accuracy: 0.5494 - precision: 0.5150 - recall: 0.6353
# Epoch 00029: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 254s 29ms/step - loss: 0.6822 - accuracy: 0.5494 - precision: 0.5150 - recall: 0.6353 - val_loss: 0.6871 - val_accuracy: 0.5369 - val_precision: 0.5028 - val_recall: 0.6334 - lr: 6.2500e-05
# Epoch 30/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6822 - accuracy: 0.5501 - precision: 0.5157 - recall: 0.6291
# Epoch 30: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00030: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 253s 29ms/step - loss: 0.6822 - accuracy: 0.5501 - precision: 0.5157 - recall: 0.6291 - val_loss: 0.6877 - val_accuracy: 0.5350 - val_precision: 0.5011 - val_recall: 0.6465 - lr: 6.2500e-05
# Epoch 31/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6819 - accuracy: 0.5504 - precision: 0.5160 - recall: 0.6327
# Epoch 00031: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 252s 29ms/step - loss: 0.6819 - accuracy: 0.5504 - precision: 0.5160 - recall: 0.6327 - val_loss: 0.6873 - val_accuracy: 0.5370 - val_precision: 0.5029 - val_recall: 0.6358 - lr: 3.1250e-05
# Epoch 32/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6816 - accuracy: 0.5515 - precision: 0.5170 - recall: 0.6312
# Epoch 00032: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 252s 29ms/step - loss: 0.6816 - accuracy: 0.5515 - precision: 0.5170 - recall: 0.6312 - val_loss: 0.6873 - val_accuracy: 0.5369 - val_precision: 0.5028 - val_recall: 0.6363 - lr: 3.1250e-05
# Epoch 33/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6814 - accuracy: 0.5509 - precision: 0.5164 - recall: 0.6330
# Epoch 00033: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 248s 29ms/step - loss: 0.6814 - accuracy: 0.5509 - precision: 0.5164 - recall: 0.6330 - val_loss: 0.6877 - val_accuracy: 0.5368 - val_precision: 0.5027 - val_recall: 0.6386 - lr: 3.1250e-05
# Epoch 34/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6813 - accuracy: 0.5520 - precision: 0.5174 - recall: 0.6325
# Epoch 34: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00034: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 248s 29ms/step - loss: 0.6813 - accuracy: 0.5520 - precision: 0.5174 - recall: 0.6325 - val_loss: 0.6875 - val_accuracy: 0.5364 - val_precision: 0.5024 - val_recall: 0.6308 - lr: 3.1250e-05
# Epoch 35/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6811 - accuracy: 0.5524 - precision: 0.5176 - recall: 0.6365
# Epoch 00035: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 255s 30ms/step - loss: 0.6811 - accuracy: 0.5524 - precision: 0.5176 - recall: 0.6365 - val_loss: 0.6874 - val_accuracy: 0.5370 - val_precision: 0.5029 - val_recall: 0.6346 - lr: 1.5625e-05
# Epoch 36/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6810 - accuracy: 0.5527 - precision: 0.5180 - recall: 0.6344
# Epoch 00036: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 258s 30ms/step - loss: 0.6810 - accuracy: 0.5527 - precision: 0.5180 - recall: 0.6344 - val_loss: 0.6873 - val_accuracy: 0.5370 - val_precision: 0.5029 - val_recall: 0.6343 - lr: 1.5625e-05
# Epoch 37/500
# 8611/8613 [============================>.] - ETA: 0s - loss: 0.6809 - accuracy: 0.5523 - precision: 0.5177 - recall: 0.6339
# Epoch 00037: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 260s 30ms/step - loss: 0.6809 - accuracy: 0.5524 - precision: 0.5177 - recall: 0.6339 - val_loss: 0.6873 - val_accuracy: 0.5376 - val_precision: 0.5035 - val_recall: 0.6327 - lr: 1.5625e-05
# Epoch 38/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6807 - accuracy: 0.5533 - precision: 0.5185 - recall: 0.6341
# Epoch 38: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00038: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 260s 30ms/step - loss: 0.6807 - accuracy: 0.5533 - precision: 0.5185 - recall: 0.6341 - val_loss: 0.6874 - val_accuracy: 0.5377 - val_precision: 0.5036 - val_recall: 0.6292 - lr: 1.5625e-05
# Epoch 39/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6808 - accuracy: 0.5527 - precision: 0.5180 - recall: 0.6342
# Epoch 00039: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 261s 30ms/step - loss: 0.6808 - accuracy: 0.5527 - precision: 0.5180 - recall: 0.6342 - val_loss: 0.6874 - val_accuracy: 0.5373 - val_precision: 0.5032 - val_recall: 0.6383 - lr: 7.8125e-06
# Epoch 40/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6806 - accuracy: 0.5527 - precision: 0.5180 - recall: 0.6341
# Epoch 00040: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 264s 31ms/step - loss: 0.6806 - accuracy: 0.5527 - precision: 0.5180 - recall: 0.6341 - val_loss: 0.6875 - val_accuracy: 0.5373 - val_precision: 0.5031 - val_recall: 0.6401 - lr: 7.8125e-06
# Epoch 41/500
# 8612/8613 [============================>.] - ETA: 0s - loss: 0.6808 - accuracy: 0.5531 - precision: 0.5183 - recall: 0.6360
# Epoch 00041: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 272s 32ms/step - loss: 0.6808 - accuracy: 0.5531 - precision: 0.5183 - recall: 0.6360 - val_loss: 0.6875 - val_accuracy: 0.5369 - val_precision: 0.5028 - val_recall: 0.6450 - lr: 7.8125e-06
# Epoch 42/500
# 8613/8613 [==============================] - ETA: 0s - loss: 0.6804 - accuracy: 0.5536 - precision: 0.5187 - recall: 0.6371Restoring model weights from the end of the best epoch: 22.
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00042: val_loss did not improve from 0.68672
# 8613/8613 [==============================] - 296s 34ms/step - loss: 0.6804 - accuracy: 0.5536 - precision: 0.5187 - recall: 0.6371 - val_loss: 0.6875 - val_accuracy: 0.5380 - val_precision: 0.5037 - val_recall: 0.6331 - lr: 7.8125e-06
# Epoch 42: early stopping
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./model/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/model_tf/assets
# INFO:tensorflow:Assets written to: ./model/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/model_tf/assets
# './model/v12.60.200.i5.d12.lstm1.sp22y1d.20240228.2/model_tf/scaler.json'

# %%
plt.plot(his_ud.history['accuracy'], label='accuracy')
plt.plot(his_ud.history['val_accuracy'], label='val_accuracy')
plt.plot(his_ud.history['loss'], label='loss')
plt.plot(his_ud.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
model_ud = keras.models.load_model(model_tf_dir_file)
scaler_ud = joblib.load(scaler_save_file)

# %%
prediction_data = cf.get_prediction_data(cf.docker_prediction_data_url, train_config_id=2059182, start="2017-07-11", end=datetime.now().strftime("%Y-%m-%d"), code="QQQ")
kline = cf.get_kline_histroy(cf.docker_kline_history_url, start="2017-07-11", end=datetime.now().strftime("%Y-%m-%d"), code='QQQ')
df = cf.his_to_df(kline)

# %%
X_prediction_scaled = train.to_prediction_scaled(prediction_data['features'], scaler_ud)
Y_ud_prediction = model_ud.predict(X_prediction_scaled)
# Out:
# 53/53 [==============================] - 2s 14ms/step

# %%
predictions_ud_series = pd.Series(Y_ud_prediction.flatten(), index=df.index)
buy_signals = np.full(df.shape[0], np.nan)  # 含 NaN 的数组，与 df 的长度一致
buy_signals[predictions_ud_series > 0.55] = df['low'][predictions_ud_series > 0.55] * 0.99
buy_markers = mpf.make_addplot(buy_signals, type='scatter', markersize=50, marker='^', color='g')

sell_signals = np.full(df.shape[0], np.nan)  # 含 NaN 的数组，与 df 的长度一致
sell_signals[predictions_ud_series < 0.1] = df['high'][predictions_ud_series < 0.1] * 1.01
sell_signals = mpf.make_addplot(sell_signals, type='scatter', markersize=50, marker='_', color='gray')

mpf.plot(df, type='candle', style='charles', addplot=[buy_markers,sell_signals], volume=True, figsize=(24, 16))
# Out:
# /usr/local/lib/python3.8/dist-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+
